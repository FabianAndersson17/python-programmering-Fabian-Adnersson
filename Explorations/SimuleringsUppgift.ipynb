# %% [markdown]
# # Rolig simulerings uppgift

# %%
import math
import matplotlib.pyplot as plt
import random

simulations = 0
withinCircle = 0
def Euclidean_Distance(x, y):
    return math.sqrt((x-0)**2 + (y-0)**2)

print(Euclidean_Distance(0.5, 0.5))
print(Euclidean_Distance(1,1))
print(Euclidean_Distance(0.5, -0.5))

plt.axes().set_aspect(1)
for _ in range(1000):
    x = random.uniform(-1, 1)
    y = random.uniform(-1, 1)
    if Euclidean_Distance(x, y) <= 1:
        plt.scatter(x, y, c = "Green")
        withinCircle += 1
    else:
        plt.scatter(x, y, c = "Red")
    simulations += 1
plt.show()

amountInside = withinCircle/simulations
print(amountInside)
# Out:
# 0.7071067811865476
# 1.4142135623730951
# 0.7071067811865476
# 0.796

# %%
import matplotlib.pyplot as plt
import random
import math

radius = 1000
withinCircle = 0
simulations = 0

plt.axes().set_aspect(1)
for _ in range(1000):
    x = random.uniform(-radius, radius)
    y = random.uniform(-radius, radius)
    if Euclidean_Distance(x, y) <= radius:
        plt.scatter(x, y, c = "Green")
        withinCircle += 1
    else:
        plt.scatter(x, y, c = "Red")
    simulations += 1
plt.show()

amountInside = withinCircle/simulations

print(amountInside)
procentInside = amountInside*100
print(f"{procentInside}%")
# Out:
# 0.768
# 76.8%
